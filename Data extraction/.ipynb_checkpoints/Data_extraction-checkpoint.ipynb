# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# C:\Users\darre\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_excel('input.xlsx')

# %%
df
# Out:
#       URL_ID                                                URL
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
# [114 rows x 2 columns]

# %%
for index,row in df.iterrows():
    url=row['URL']
    url_id=row['URL_ID']
    try:
        response=requests.get(url)
        response.raise_for_status()
        html_content=response.text
    except requests.exceptions.RequestException as e:
        print(f"Error fetching content for {url}:{e}")
    soup=BeautifulSoup(html_content,'html.parser')
              
    title_tag=soup.find("h1",class_='entry-title') 
    title=title_tag.text if title_tag else "No title"
              
    article_text='\n'.join([p.text for p in soup.find_all('p',class_="")])
              
    output_file=f'Extracted_files/{url_id}.txt'
    
    with open(output_file,'w',encoding='utf-8') as file:
              file.write(f'Title: {title}\n\n')
              file.write(article_text)
    print(f'Article extracted and saved for {url_id}')

print('Extraction and saving completed.')
# Out:
# Article extracted and saved for 123.0
# Article extracted and saved for 321.0
# Article extracted and saved for 2345.0
# Article extracted and saved for 4321.0
# Article extracted and saved for 432.0
# Article extracted and saved for 2893.8
# Article extracted and saved for 3355.6
# Article extracted and saved for 3817.4
# Article extracted and saved for 4279.2
# Article extracted and saved for 4741.0
# Article extracted and saved for 5202.8
# Article extracted and saved for 5664.6
# Article extracted and saved for 6126.4
# Article extracted and saved for 6588.2
# Article extracted and saved for 7050.0
# Article extracted and saved for 7511.8
# Article extracted and saved for 7973.6
# Article extracted and saved for 8435.4
# Article extracted and saved for 8897.2
# Article extracted and saved for 9359.0
# Article extracted and saved for 9820.8
# Article extracted and saved for 10282.6
# Article extracted and saved for 10744.4
# Article extracted and saved for 11206.2
# ...

# %%
url1=df['URL'][0]
url1
response=requests.get(url1)
response.raise_for_status()
html_content=response.text
soup=BeautifulSoup(html_content,'html.parser')
title_tag=soup.find("h1",class_='entry-title') 
title=title_tag.text if title_tag else "No title"
article_text='\n'.join([p.text for p in soup.find_all('p',class_="")])
          
output_file='Extracted_files/demo.txt'
    
with open(output_file,'w',encoding='utf-8') as file:
    file.write(f'Title: {title}\n\n')
    file.write(article_text)
